# %% [markdown]
# <a href="https://colab.research.google.com/github/Lewislou/Pytorch-pratical-Learning/blob/master/6_1_TransferLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Transfer Learning and Fine Tuning

# %% [markdown]
# __Before starting, we recommend you enable GPU acceleration if you're running on Colab.__

# %%
# Execute this code block to install dependencies when running on colab
try:
    import torch
except:
    from os.path import exists
    from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
    platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())
    cuda_output = !ldconfig -p|grep cudart.so|sed -e 's/.*\.\([0-9]*\)\.\([0-9]*\)$/cu\1\2/'
    accelerator = cuda_output[0] if exists('/dev/nvidia0') else 'cpu'

    # !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-1.0.0-{platform}-linux_x86_64.whl torchvision

try: 
    import torchbearer
except:
    # !pip install torchbearer
# Out:
# Collecting torchbearer
#   Downloading https://files.pythonhosted.org/packages/ff/e9/4049a47dd2e5b6346a2c5d215b0c67dce814afbab1cd54ce024533c4834e/torchbearer-0.5.3-py3-none-any.whl (138kB)
#      |████████████████████████████████| 143kB 11.0MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchbearer) (1.18.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from torchbearer) (4.38.0)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from torchbearer) (1.5.0+cu101)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch>=1.0.0->torchbearer) (0.16.0)
# Installing collected packages: torchbearer
# Successfully installed torchbearer-0.5.3

# %% [markdown]
# ## Getting started
#
# Start by downloading and unzipping the data set. The code in the following block will download and unzip the data we're going to use.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from os.path import exists
if not exists('data'):
    # !wget -O boat-data.zip https://artist-cloud.ecs.soton.ac.uk/index.php/s/eAhIkhhdxgmhRHj/download
    # !unzip boat-data.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: __MACOSX/data/train/Water/._20130307_132914_88100.jpg
#   inflating: data/train/Water/20130307_094447_52382.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_094447_52382.jpg
#   inflating: data/train/Water/20130306_130050_70834.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_130050_70834.jpg
#   inflating: data/train/Water/20130307_153426_05218.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_153426_05218.jpg
#   inflating: data/train/Water/20130305_143831_94019.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_143831_94019.jpg
#   inflating: data/train/Water/20130305_130423_80505.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_130423_80505.jpg
#   inflating: data/train/Water/20130304_125717_21597.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_125717_21597.jpg
#   inflating: data/train/Water/20130305_131821_81936.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_131821_81936.jpg
#   inflating: data/train/Water/20130307_120826_77492.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_120826_77492.jpg
#   inflating: data/train/Water/20130305_102023_54494.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_102023_54494.jpg
#   inflating: data/train/Water/20130305_125457_79747.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_125457_79747.jpg
#   inflating: data/train/Water/20130304_080029_29031.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_080029_29031.jpg
#   inflating: data/train/Water/20130305_074739_29480.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_074739_29480.jpg
#   inflating: data/train/Water/20130306_102150_48868.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_102150_48868.jpg
#   inflating: data/train/Water/20130304_071406_20190.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_071406_20190.jpg
#   inflating: data/train/Water/20130306_061152_04549.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_061152_04549.jpg
#   inflating: data/train/Water/20130304_141619_34473.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_141619_34473.jpg
#   inflating: data/train/Water/20130305_103759_57020.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_103759_57020.jpg
#   inflating: data/train/Water/20130305_071803_23168.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_071803_23168.jpg
#   inflating: data/train/Water/20130305_122708_76331.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_122708_76331.jpg
#   inflating: data/train/Water/20130306_061520_04923.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_061520_04923.jpg
#   inflating: data/train/Water/20130305_071053_21844.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_071053_21844.jpg
#   inflating: data/train/Water/20130307_131836_86962.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_131836_86962.jpg
#   inflating: data/train/Water/20130307_113253_72298.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_113253_72298.jpg
#   inflating: data/train/Water/20130307_083812_37653.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_083812_37653.jpg
#   inflating: data/train/Water/20130307_103933_62286.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_103933_62286.jpg
#   inflating: data/train/Water/20130307_122611_79629.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_122611_79629.jpg
#   inflating: data/train/Water/20130305_142208_91823.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_142208_91823.jpg
#   inflating: data/train/Water/20130307_115809_76014.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_115809_76014.jpg
#   inflating: data/train/Water/20130304_161921_54258.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_161921_54258.jpg
#   inflating: data/train/Water/20130307_145922_00344.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_145922_00344.jpg
#   inflating: data/train/Water/20130304_122811_16980.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_122811_16980.jpg
#   inflating: data/train/Water/20130305_111144_64382.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_111144_64382.jpg
#   inflating: data/train/Water/20130305_093631_46685.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_093631_46685.jpg
#   inflating: data/train/Water/20130306_131806_72899.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_131806_72899.jpg
#   inflating: data/train/Water/20130304_140315_32062.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_140315_32062.jpg
#   inflating: data/train/Water/20130305_101355_53485.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_101355_53485.jpg
#   inflating: data/train/Water/20130306_105612_54069.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_105612_54069.jpg
#   inflating: data/train/Water/20130306_131013_71971.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_131013_71971.jpg
#   inflating: data/train/Water/20130306_092817_39618.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_092817_39618.jpg
#   inflating: data/train/Water/20130307_105047_64995.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_105047_64995.jpg
#   inflating: data/train/Water/20130305_095523_50137.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_095523_50137.jpg
#   inflating: data/train/Water/20130307_111723_69600.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_111723_69600.jpg
#   inflating: data/train/Water/20130305_111115_64119.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_111115_64119.jpg
#   inflating: data/train/Water/20130307_084038_38046.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_084038_38046.jpg
#   inflating: data/train/Water/20130304_062610_09565.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_062610_09565.jpg
#   inflating: data/train/Water/20130305_120445_72341.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_120445_72341.jpg
#   inflating: data/train/Water/20130306_132542_73710.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_132542_73710.jpg
#   inflating: data/train/Water/20130305_085121_39945.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_085121_39945.jpg
#   inflating: data/train/Water/20130304_073850_24275.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_073850_24275.jpg
#   inflating: data/train/Water/20130304_064217_13051.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_064217_13051.jpg
#   inflating: data/train/Water/20130307_123141_80445.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_123141_80445.jpg
#   inflating: data/train/Water/20130306_102257_48897.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_102257_48897.jpg
#   inflating: data/train/Water/20130305_090912_42027.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_090912_42027.jpg
#   inflating: data/train/Water/20130307_061736_10571.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_061736_10571.jpg
#   inflating: data/train/Water/20130305_114237_68554.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_114237_68554.jpg
#   inflating: data/train/Water/20130307_090311_42590.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_090311_42590.jpg
#   inflating: data/train/Water/20130305_071604_22753.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_071604_22753.jpg
#   inflating: data/train/Water/20130305_085133_39836.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_085133_39836.jpg
#   inflating: data/train/Water/20130304_080731_30057.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_080731_30057.jpg
#   inflating: data/train/Water/20130307_115153_75225.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_115153_75225.jpg
#   inflating: data/train/Water/20130306_074817_22258.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_074817_22258.jpg
#   inflating: data/train/Water/20130307_095704_55377.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_095704_55377.jpg
#   inflating: data/train/Water/20130307_121758_78965.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_121758_78965.jpg
#   inflating: data/train/Water/20130305_163704_09184.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_163704_09184.jpg
#   inflating: data/train/Water/20130304_131537_24319.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_131537_24319.jpg
#   inflating: data/train/Water/20130306_161627_96289.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_161627_96289.jpg
#   inflating: data/train/Water/20130305_064431_16763.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_064431_16763.jpg
#   inflating: data/train/Water/20130304_060825_07399.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_060825_07399.jpg
#   inflating: data/train/Water/20130307_144710_98417.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_144710_98417.jpg
#   inflating: data/train/Water/20130306_062121_05974.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_062121_05974.jpg
#   inflating: data/train/Water/20130305_161347_06517.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_161347_06517.jpg
#   inflating: data/train/Water/20130307_084132_38476.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_084132_38476.jpg
#   inflating: data/train/Water/20130307_071815_21838.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_071815_21838.jpg
#   inflating: data/train/Water/20130307_074039_26845.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_074039_26845.jpg
#   inflating: data/train/Water/20130305_134438_84852.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_134438_84852.jpg
#   inflating: data/train/Water/20130304_122658_16746.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_122658_16746.jpg
#   inflating: data/train/Water/20130307_130139_84303.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_130139_84303.jpg
#   inflating: data/train/Water/20130307_061821_10653.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_061821_10653.jpg
#   inflating: data/train/Water/20130305_124609_78671.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_124609_78671.jpg
#   inflating: data/train/Water/20130306_154448_91633.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_154448_91633.jpg
#   inflating: data/train/Water/20130307_091247_44766.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_091247_44766.jpg
#   inflating: data/train/Water/20130307_104524_63624.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_104524_63624.jpg
#   inflating: data/train/Water/20130305_120913_73279.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_120913_73279.jpg
#   inflating: data/train/Water/20130307_155025_07397.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_155025_07397.jpg
#   inflating: data/train/Water/20130307_095510_55053.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_095510_55053.jpg
#   inflating: data/train/Water/20130305_163639_09143.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_163639_09143.jpg
#   inflating: data/train/Water/20130307_084051_37997.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_084051_37997.jpg
#   inflating: data/train/Water/20130306_162949_97760.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_162949_97760.jpg
#   inflating: data/train/Water/20130305_105559_60209.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_105559_60209.jpg
#   inflating: data/train/Water/20130304_120152_11412.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_120152_11412.jpg
#   inflating: data/train/Water/20130305_160710_05289.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_160710_05289.jpg
#   inflating: data/train/Water/20130307_123737_81313.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_123737_81313.jpg
#   inflating: data/train/Water/20130306_130558_71561.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_130558_71561.jpg
#   inflating: data/train/Water/20130305_072843_25246.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_072843_25246.jpg
#   inflating: data/train/Water/20130305_102806_55472.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_102806_55472.jpg
#   inflating: data/train/Water/20130305_165636_11818.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_165636_11818.jpg
#   inflating: data/train/Water/20130307_151514_02476.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_151514_02476.jpg
#   inflating: data/train/Water/20130307_095327_54423.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_095327_54423.jpg
#   inflating: data/train/Water/20130306_112259_57254.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_112259_57254.jpg
#   inflating: data/train/Water/20130305_143408_93358.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_143408_93358.jpg
#   inflating: data/train/Water/20130305_120221_72083.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_120221_72083.jpg
#   inflating: data/train/Water/20130305_093754_47018.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_093754_47018.jpg
#   inflating: data/train/Water/20130304_121208_13415.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_121208_13415.jpg
#   inflating: data/train/Water/20130307_084624_39422.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_084624_39422.jpg
#   inflating: data/train/Water/20130307_090250_42551.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_090250_42551.jpg
#   inflating: data/train/Water/20130307_094600_52693.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_094600_52693.jpg
#   inflating: data/train/Water/20130307_141605_94472.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_141605_94472.jpg
#   inflating: data/train/Water/20130305_072402_24342.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_072402_24342.jpg
#   inflating: data/train/Water/20130307_073801_26252.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_073801_26252.jpg
#   inflating: data/train/Water/20130307_143724_97132.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_143724_97132.jpg
#   inflating: data/train/Water/20130305_072617_24922.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_072617_24922.jpg
#   inflating: data/train/Water/20130304_054535_04576.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_054535_04576.jpg
#   inflating: data/train/Water/20130306_153255_90156.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_153255_90156.jpg
#   inflating: data/train/Water/20130304_082857_34963.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_082857_34963.jpg
#   inflating: data/train/Water/20130307_103626_61717.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_103626_61717.jpg
#   inflating: data/train/Water/20130307_110819_68358.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_110819_68358.jpg
#   inflating: data/train/Water/20130305_080102_31710.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_080102_31710.jpg
#   inflating: data/train/Water/20130307_145224_99109.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_145224_99109.jpg
#   inflating: data/train/Water/20130306_112147_57123.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_112147_57123.jpg
#   inflating: data/train/Water/20130307_082154_34786.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_082154_34786.jpg
#   inflating: data/train/Water/20130304_084000_36986.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_084000_36986.jpg
#   inflating: data/train/Water/20130307_080045_30997.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_080045_30997.jpg
#   inflating: data/train/Water/20130306_095047_43385.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_095047_43385.jpg
#   inflating: data/train/Water/20130304_060747_07315.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_060747_07315.jpg
#   inflating: data/train/Water/20130305_080635_32451.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_080635_32451.jpg
#   inflating: data/train/Water/20130305_120716_72953.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_120716_72953.jpg
#   inflating: data/train/Water/20130307_092303_47450.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_092303_47450.jpg
#   inflating: data/train/Water/20130306_073749_20268.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_073749_20268.jpg
#   inflating: data/train/Water/20130305_142821_92249.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_142821_92249.jpg
#   inflating: data/train/Water/20130305_061922_11492.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_061922_11492.jpg
#   inflating: data/train/Water/20130307_104016_62514.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_104016_62514.jpg
#   inflating: data/train/Water/20130304_072754_22899.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_072754_22899.jpg
#   inflating: data/train/Water/20130307_150658_01513.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_150658_01513.jpg
#   inflating: data/train/Water/20130307_073428_25180.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_073428_25180.jpg
#   inflating: data/train/Water/20130307_105213_65454.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_105213_65454.jpg
#   inflating: data/train/Water/20130305_112724_66544.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_112724_66544.jpg
#   inflating: data/train/Water/20130304_055811_05755.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_055811_05755.jpg
#   inflating: data/train/Water/20130307_072752_23803.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_072752_23803.jpg
#   inflating: data/train/Water/20130305_130201_80250.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_130201_80250.jpg
#   inflating: data/train/Water/20130307_100017_56023.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_100017_56023.jpg
#   inflating: data/train/Water/20130306_102626_49567.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_102626_49567.jpg
#   inflating: data/train/Water/20130306_084606_32331.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_084606_32331.jpg
#   inflating: data/train/Water/20130304_125729_21655.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_125729_21655.jpg
#   inflating: data/train/Water/20130307_073058_24535.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_073058_24535.jpg
#   inflating: data/train/Water/20130307_085813_41739.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_085813_41739.jpg
#   inflating: data/train/Water/20130305_075144_29961.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_075144_29961.jpg
#   inflating: data/train/Water/20130304_065526_15999.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_065526_15999.jpg
#   inflating: data/train/Water/20130304_072059_21437.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_072059_21437.jpg
#   inflating: data/train/Water/20130304_115914_11008.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_115914_11008.jpg
#   inflating: data/train/Water/20130307_072638_23630.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_072638_23630.jpg
#   inflating: data/train/Water/20130307_122437_79554.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_122437_79554.jpg
#   inflating: data/train/Water/20130307_081819_34134.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_081819_34134.jpg
#   inflating: data/train/Water/20130306_062349_06218.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_062349_06218.jpg
#   inflating: data/train/Water/20130304_073826_24264.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_073826_24264.jpg
#   inflating: data/train/Water/20130307_082720_35746.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_082720_35746.jpg
#   inflating: data/train/Water/20130305_071139_22086.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_071139_22086.jpg
#   inflating: data/train/Water/20130307_153541_05294.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_153541_05294.jpg
#   inflating: data/train/Water/20130305_144116_94495.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_144116_94495.jpg
#   inflating: data/train/Water/20130307_112024_70036.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_112024_70036.jpg
#   inflating: data/train/Water/20130305_142403_91956.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_142403_91956.jpg
#   inflating: data/train/Water/20130305_100042_51116.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_100042_51116.jpg
#   inflating: data/train/Water/20130307_112846_71522.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_112846_71522.jpg
#   inflating: data/train/Water/20130307_110934_68618.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_110934_68618.jpg
#   inflating: data/train/Water/20130307_121420_78449.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_121420_78449.jpg
#   inflating: data/train/Water/20130305_155746_04374.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_155746_04374.jpg
#   inflating: data/train/Water/20130305_104401_57772.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_104401_57772.jpg
#   inflating: data/train/Water/20130306_130635_71685.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_130635_71685.jpg
#   inflating: data/train/Water/20130304_062654_09666.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_062654_09666.jpg
#   inflating: data/train/Water/20130306_074113_20848.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_074113_20848.jpg
#   inflating: data/train/Water/20130307_101109_57734.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_101109_57734.jpg
#   inflating: data/train/Water/20130305_081451_33686.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_081451_33686.jpg
#   inflating: data/train/Water/20130305_152733_00350.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_152733_00350.jpg
#   inflating: data/train/Water/20130305_075100_29965.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_075100_29965.jpg
#   inflating: data/train/Water/20130305_143951_94345.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_143951_94345.jpg
#   inflating: data/train/Water/20130307_090510_42867.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_090510_42867.jpg
#   inflating: data/train/Water/20130304_063718_11505.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_063718_11505.jpg
#   inflating: data/train/Water/20130304_120155_11460.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_120155_11460.jpg
#   inflating: data/train/Water/20130306_055325_01652.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_055325_01652.jpg
#   inflating: data/train/Water/20130306_125500_70463.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_125500_70463.jpg
#   inflating: data/train/Water/20130305_061418_10956.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_061418_10956.jpg
#   inflating: data/train/Water/20130306_131749_72862.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_131749_72862.jpg
#   inflating: data/train/Water/20130307_091829_46212.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_091829_46212.jpg
#   inflating: data/train/Water/20130305_142753_92227.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_142753_92227.jpg
#   inflating: data/train/Water/20130306_075036_22493.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_075036_22493.jpg
#   inflating: data/train/Water/20130306_121108_64082.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_121108_64082.jpg
#   inflating: data/train/Water/20130307_063557_12963.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_063557_12963.jpg
#   inflating: data/train/Water/20130306_094414_42228.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_094414_42228.jpg
#   inflating: data/train/Water/20130306_131755_72842.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_131755_72842.jpg
#   inflating: data/train/Water/20130307_105040_64775.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_105040_64775.jpg
#   inflating: data/train/Water/20130307_140420_93026.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_140420_93026.jpg
#   inflating: data/train/Water/20130306_131858_72940.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_131858_72940.jpg
#   inflating: data/train/Water/20130304_132539_26140.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_132539_26140.jpg
#   inflating: data/train/Water/20130304_065349_15341.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_065349_15341.jpg
#   inflating: data/train/Water/20130305_110327_61877.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_110327_61877.jpg
#   inflating: data/train/Water/20130307_131415_86005.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_131415_86005.jpg
#   inflating: data/train/Water/20130307_141810_94791.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_141810_94791.jpg
#   inflating: data/train/Water/20130305_074216_28241.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_074216_28241.jpg
#   inflating: data/train/Water/20130306_102742_49741.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_102742_49741.jpg
#   inflating: data/train/Water/20130307_065912_17698.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_065912_17698.jpg
#   inflating: data/train/Water/20130304_060554_06698.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_060554_06698.jpg
#   inflating: data/train/Water/20130307_070944_19503.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_070944_19503.jpg
#   inflating: data/train/Water/20130307_114451_74251.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_114451_74251.jpg
#   inflating: data/train/Water/20130304_074454_25607.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_074454_25607.jpg
#   inflating: data/train/Water/20130305_075205_30294.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_075205_30294.jpg
#   inflating: data/train/Water/20130306_135321_76721.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_135321_76721.jpg
#   inflating: data/train/Water/20130306_164406_00070.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_164406_00070.jpg
#   inflating: data/train/Water/20130304_071956_21121.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_071956_21121.jpg
#   inflating: data/train/Water/20130305_105949_61218.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_105949_61218.jpg
#   inflating: data/train/Water/20130305_151608_98772.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_151608_98772.jpg
#   inflating: data/train/Water/20130307_063635_13070.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_063635_13070.jpg
#   inflating: data/train/Water/20130306_160016_94031.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_160016_94031.jpg
#   inflating: data/train/Water/20130307_083255_36631.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_083255_36631.jpg
#   inflating: data/train/Water/20130307_134617_90179.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_134617_90179.jpg
#   inflating: data/train/Water/20130304_142135_35085.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_142135_35085.jpg
#   inflating: data/train/Water/20130306_084521_32156.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_084521_32156.jpg
#   inflating: data/train/Water/20130304_081554_31646.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_081554_31646.jpg
#   inflating: data/train/Water/20130306_071516_16199.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_071516_16199.jpg
#   inflating: data/train/Water/20130306_102102_48657.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_102102_48657.jpg
#   inflating: data/train/Water/20130306_115046_62352.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_115046_62352.jpg
#   inflating: data/train/Water/20130306_104553_52567.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_104553_52567.jpg
#   inflating: data/train/Water/20130306_063133_07681.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_063133_07681.jpg
#   inflating: data/train/Water/20130307_064203_14386.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_064203_14386.jpg
#   inflating: data/train/Water/20130304_170402_60220.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_170402_60220.jpg
#   inflating: data/train/Water/20130307_074737_28210.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_074737_28210.jpg
#   inflating: data/train/Water/20130307_071658_21587.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_071658_21587.jpg
#   inflating: data/train/Water/20130307_060812_09363.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_060812_09363.jpg
#   inflating: data/train/Water/20130306_083144_29041.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_083144_29041.jpg
#   inflating: data/train/Water/20130306_124447_68852.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_124447_68852.jpg
#   inflating: data/train/Water/20130306_075328_23039.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_075328_23039.jpg
#   inflating: data/train/Water/20130305_103504_56583.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_103504_56583.jpg
#   inflating: data/train/Water/20130307_111558_69390.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_111558_69390.jpg
#   inflating: data/train/Water/20130304_081711_31946.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_081711_31946.jpg
#   inflating: data/train/Water/20130304_142342_35299.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_142342_35299.jpg
#   inflating: data/train/Water/20130304_070338_17552.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_070338_17552.jpg
#   inflating: data/train/Water/20130305_115208_70247.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_115208_70247.jpg
#   inflating: data/train/Water/20130307_062025_10766.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_062025_10766.jpg
#   inflating: data/train/Water/20130306_144154_82947.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_144154_82947.jpg
#   inflating: data/train/Water/20130306_114431_61187.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_114431_61187.jpg
#   inflating: data/train/Water/20130307_075229_29627.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_075229_29627.jpg
#   inflating: data/train/Water/20130305_140134_88130.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_140134_88130.jpg
#   inflating: data/train/Water/20130306_154936_92360.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_154936_92360.jpg
#   inflating: data/train/Water/20130305_090734_41889.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_090734_41889.jpg
#   inflating: data/train/Water/20130307_092344_47883.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_092344_47883.jpg
#   inflating: data/train/Water/20130307_123423_80682.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_123423_80682.jpg
#   inflating: data/train/Water/20130307_141621_94486.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_141621_94486.jpg
#   inflating: data/train/Water/20130304_114117_07829.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_114117_07829.jpg
#   inflating: data/train/Water/20130305_150823_97363.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_150823_97363.jpg
#   inflating: data/train/Water/20130307_143925_97364.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_143925_97364.jpg
#   inflating: data/train/Water/20130305_073105_25639.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_073105_25639.jpg
#   inflating: data/train/Water/20130307_144053_97501.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_144053_97501.jpg
#   inflating: data/train/Water/20130307_075719_30396.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_075719_30396.jpg
#   inflating: data/train/Water/20130307_092508_48113.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_092508_48113.jpg
#   inflating: data/train/Water/20130305_131312_81351.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_131312_81351.jpg
#   inflating: data/train/Water/20130307_072933_24289.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_072933_24289.jpg
#   inflating: data/train/Water/20130306_122700_66541.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_122700_66541.jpg
#   inflating: data/train/Water/20130305_070516_20587.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_070516_20587.jpg
#   inflating: data/train/Water/20130306_153126_89635.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_153126_89635.jpg
#   inflating: data/train/Water/20130305_154419_02445.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_154419_02445.jpg
#   inflating: data/train/Water/20130306_061804_05384.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_061804_05384.jpg
#   inflating: data/train/Water/20130307_080033_31031.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_080033_31031.jpg
#   inflating: data/train/Water/20130307_143204_96528.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_143204_96528.jpg
#   inflating: data/train/Water/20130306_092102_38464.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_092102_38464.jpg
#   inflating: data/train/Water/20130306_103922_51245.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_103922_51245.jpg
#   inflating: data/train/Water/20130307_080512_32105.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_080512_32105.jpg
#   inflating: data/train/Water/20130306_091359_37353.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_091359_37353.jpg
#   inflating: data/train/Water/20130304_120331_11583.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_120331_11583.jpg
#   inflating: data/train/Water/20130304_081934_32631.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_081934_32631.jpg
#   inflating: data/train/Water/20130306_055104_01310.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_055104_01310.jpg
#   inflating: data/train/Water/20130307_104516_63636.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_104516_63636.jpg
#   inflating: data/train/Water/20130307_055229_06745.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_055229_06745.jpg
#   inflating: data/train/Water/20130306_152852_89559.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_152852_89559.jpg
#   inflating: data/train/Water/20130306_070714_14878.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_070714_14878.jpg
#   inflating: data/train/Water/20130305_135226_86177.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_135226_86177.jpg
#   inflating: data/train/Water/20130306_161138_95462.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_161138_95462.jpg
#   inflating: data/train/Water/20130306_155655_93350.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_155655_93350.jpg
#   inflating: data/train/Water/20130307_142948_96289.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_142948_96289.jpg
#   inflating: data/train/Water/20130305_133950_84490.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_133950_84490.jpg
#   inflating: data/train/Water/20130304_152410_45922.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_152410_45922.jpg
#   inflating: data/train/Water/20130305_111742_65058.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_111742_65058.jpg
#   inflating: data/train/Water/20130304_060404_06578.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_060404_06578.jpg
#   inflating: data/train/Water/20130307_131403_85965.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_131403_85965.jpg
#   inflating: data/train/Water/20130304_154815_49909.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_154815_49909.jpg
#   inflating: data/train/Water/20130306_135458_76892.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_135458_76892.jpg
#   inflating: data/train/Water/20130305_133536_84087.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_133536_84087.jpg
#   inflating: data/train/Water/20130305_135356_86239.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_135356_86239.jpg
#   inflating: data/train/Water/20130304_141100_33342.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_141100_33342.jpg
#   inflating: data/train/Water/20130306_134127_75560.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_134127_75560.jpg
#   inflating: data/train/Water/20130305_062536_13042.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_062536_13042.jpg
#   inflating: data/train/Water/20130304_080328_29501.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_080328_29501.jpg
#   inflating: data/train/Water/20130306_130339_71210.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_130339_71210.jpg
#   inflating: data/train/Water/20130306_105817_54166.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_105817_54166.jpg
#   inflating: data/train/Water/20130305_150634_97234.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_150634_97234.jpg
#   inflating: data/train/Water/20130306_142659_81125.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_142659_81125.jpg
#   inflating: data/train/Water/20130305_095437_50042.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_095437_50042.jpg
#   inflating: data/train/Water/20130306_094709_42950.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_094709_42950.jpg
#   inflating: data/train/Water/20130304_071809_20838.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_071809_20838.jpg
#   inflating: data/train/Water/20130307_104148_63058.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_104148_63058.jpg
#   inflating: data/train/Water/20130307_081435_33443.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_081435_33443.jpg
#   inflating: data/train/Water/20130307_065536_16754.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_065536_16754.jpg
#   inflating: data/train/Water/20130304_073749_24132.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_073749_24132.jpg
#   inflating: data/train/Water/20130307_143412_96672.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_143412_96672.jpg
#   inflating: data/train/Water/20130305_070613_20871.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_070613_20871.jpg
#   inflating: data/train/Water/20130304_120604_12281.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_120604_12281.jpg
#   inflating: data/train/Water/20130304_141212_33530.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_141212_33530.jpg
#   inflating: data/train/Water/20130306_154129_91355.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_154129_91355.jpg
#   inflating: data/train/Water/20130306_110154_54676.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_110154_54676.jpg
#   inflating: data/train/Water/20130304_164557_57797.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_164557_57797.jpg
#   inflating: data/train/Water/20130304_073419_23776.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_073419_23776.jpg
#   inflating: data/train/Water/20130305_091534_43643.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_091534_43643.jpg
#   inflating: data/train/Water/20130307_140106_92395.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_140106_92395.jpg
#   inflating: data/train/Water/20130304_155816_50729.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_155816_50729.jpg
#   inflating: data/train/Water/20130307_123642_81269.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_123642_81269.jpg
#   inflating: data/train/Water/20130307_062853_11730.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_062853_11730.jpg
#   inflating: data/train/Water/20130306_135515_76934.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_135515_76934.jpg
#   inflating: data/train/Water/20130307_133355_88689.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_133355_88689.jpg
#   inflating: data/train/Water/20130304_062040_08882.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_062040_08882.jpg
#   inflating: data/train/Water/20130305_154208_02169.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_154208_02169.jpg
#   inflating: data/train/Water/20130307_103532_61547.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_103532_61547.jpg
#   inflating: data/train/Water/20130304_071550_20436.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_071550_20436.jpg
#   inflating: data/train/Water/20130305_151309_98323.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_151309_98323.jpg
#   inflating: data/train/Water/20130304_072645_22775.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_072645_22775.jpg
#   inflating: data/train/Water/20130307_071828_21858.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_071828_21858.jpg
#   inflating: data/train/Water/20130306_113856_59481.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_113856_59481.jpg
#   inflating: data/train/Water/20130306_164042_99586.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_164042_99586.jpg
#   inflating: data/train/Water/20130306_062453_06558.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_062453_06558.jpg
#   inflating: data/train/Water/20130306_162138_96810.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_162138_96810.jpg
#   inflating: data/train/Water/20130307_082543_35382.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_082543_35382.jpg
#   inflating: data/train/Water/20130305_095149_49579.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_095149_49579.jpg
#   inflating: data/train/Water/20130305_152502_99938.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_152502_99938.jpg
#   inflating: data/train/Water/20130304_153151_47074.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_153151_47074.jpg
#   inflating: data/train/Water/20130305_083041_35591.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_083041_35591.jpg
#   inflating: data/train/Water/20130306_090103_34599.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_090103_34599.jpg
#   inflating: data/train/Water/20130305_161004_05840.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_161004_05840.jpg
#   inflating: data/train/Water/20130305_121030_73355.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_121030_73355.jpg
#   inflating: data/train/Water/20130305_061955_11539.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_061955_11539.jpg
#   inflating: data/train/Water/20130305_062814_13626.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_062814_13626.jpg
#   inflating: data/train/Water/20130306_080604_25141.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_080604_25141.jpg
#   inflating: data/train/Water/20130305_103546_56771.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_103546_56771.jpg
#   inflating: data/train/Water/20130305_135714_86737.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_135714_86737.jpg
#   inflating: data/train/Water/20130306_133516_74646.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_133516_74646.jpg
#   inflating: data/train/Water/20130307_112705_71113.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_112705_71113.jpg
#   inflating: data/train/Water/20130305_132011_82194.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_132011_82194.jpg
#   inflating: data/train/Water/20130307_143030_96389.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_143030_96389.jpg
#   inflating: data/train/Water/20130304_144856_40411.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_144856_40411.jpg
#   inflating: data/train/Water/20130307_111137_68868.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_111137_68868.jpg
#   inflating: data/train/Water/20130307_071410_20809.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_071410_20809.jpg
#   inflating: data/train/Water/20130304_061626_08415.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_061626_08415.jpg
#   inflating: data/train/Water/20130307_133030_88212.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_133030_88212.jpg
#   inflating: data/train/Water/20130304_145122_40754.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_145122_40754.jpg
#   inflating: data/train/Water/20130305_112102_65518.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_112102_65518.jpg
#   inflating: data/train/Water/20130304_062752_09766.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_062752_09766.jpg
#   inflating: data/train/Water/20130304_072147_21620.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_072147_21620.jpg
#   inflating: data/train/Water/20130307_093710_50674.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_093710_50674.jpg
#   inflating: data/train/Water/20130305_064029_15386.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_064029_15386.jpg
#   inflating: data/train/Water/20130305_143656_93744.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_143656_93744.jpg
#   inflating: data/train/Water/20130304_155231_50238.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_155231_50238.jpg
#   inflating: data/train/Water/20130307_105851_66723.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_105851_66723.jpg
#   inflating: data/train/Water/20130304_113626_07067.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_113626_07067.jpg
#   inflating: data/train/Water/20130307_114112_73796.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_114112_73796.jpg
#   inflating: data/train/Water/20130304_081431_31422.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_081431_31422.jpg
#   inflating: data/train/Water/20130306_145757_85536.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_145757_85536.jpg
#   inflating: data/train/Water/20130307_113923_73225.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_113923_73225.jpg
#   inflating: data/train/Water/20130304_075747_28538.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_075747_28538.jpg
#   inflating: data/train/Water/20130305_061248_10733.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_061248_10733.jpg
#   inflating: data/train/Water/20130304_130201_22104.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_130201_22104.jpg
#   inflating: data/train/Water/20130307_113822_73210.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_113822_73210.jpg
#   inflating: data/train/Water/20130307_123932_81526.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_123932_81526.jpg
#   inflating: data/train/Water/20130305_161233_06334.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_161233_06334.jpg
#   inflating: data/train/Water/20130305_064457_16897.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_064457_16897.jpg
#   inflating: data/train/Water/20130307_153049_04548.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_153049_04548.jpg
#   inflating: data/train/Water/20130304_082226_33509.jpg
#   inflating: __MACOSX/data/train/Water/._20130304_082226_33509.jpg
#   inflating: data/train/Water/20130307_065619_16844.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_065619_16844.jpg
#   inflating: data/train/Water/20130306_061514_04916.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_061514_04916.jpg
#   inflating: data/train/Water/20130306_150917_87008.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_150917_87008.jpg
#   inflating: data/train/Water/20130306_080822_25516.jpg
#   inflating: __MACOSX/data/train/Water/._20130306_080822_25516.jpg
#   inflating: data/train/Water/20130305_075520_30773.jpg
#   inflating: __MACOSX/data/train/Water/._20130305_075520_30773.jpg
#   inflating: data/train/Water/20130307_100746_57007.jpg
#   inflating: __MACOSX/data/train/Water/._20130307_100746_57007.jpg
# ...
#   inflating: __MACOSX/data/train/Barchino/._20130305_140612_89584.jpg
#   inflating: data/train/Barchino/20130307_080626_32198.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130307_080626_32198.jpg
#   inflating: data/train/Barchino/20130305_160229_04609.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_160229_04609.jpg
#   inflating: data/train/Barchino/20130410_110128_71665.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130410_110128_71665.jpg
#   inflating: data/train/Barchino/20130410_090820_50975.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130410_090820_50975.jpg
#   inflating: data/train/Barchino/20130305_160658_05431.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_160658_05431.jpg
#   inflating: data/train/Barchino/20130306_084943_32747.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130306_084943_32747.jpg
#   inflating: data/train/Barchino/20130304_081021_30544.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_081021_30544.jpg
#   inflating: data/train/Barchino/20130305_073913_27463.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_073913_27463.jpg
#   inflating: data/train/Barchino/20130307_123250_80561.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130307_123250_80561.jpg
#   inflating: data/train/Barchino/20130306_112928_58057.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130306_112928_58057.jpg
#   inflating: data/train/Barchino/20130410_101338_63346.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130410_101338_63346.jpg
#   inflating: data/train/Barchino/20130304_151342_44038.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_151342_44038.jpg
#   inflating: data/train/Barchino/20130306_112542_57655.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130306_112542_57655.jpg
#   inflating: data/train/Barchino/20130305_150033_96587.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_150033_96587.jpg
#   inflating: data/train/Barchino/20130305_152256_99517.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_152256_99517.jpg
#   inflating: data/train/Barchino/20130305_111335_64560.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_111335_64560.jpg
#   inflating: data/train/Barchino/20130304_153243_47442.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_153243_47442.jpg
#   inflating: data/train/Barchino/20130304_084601_38273.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_084601_38273.jpg
#   inflating: data/train/Barchino/20130305_122838_76612.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_122838_76612.jpg
#   inflating: data/train/Barchino/20130307_111718_69583.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130307_111718_69583.jpg
#   inflating: data/train/Barchino/20130307_085830_41871.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130307_085830_41871.jpg
#   inflating: data/train/Barchino/20130410_081047_36787.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130410_081047_36787.jpg
#   inflating: data/train/Barchino/20130304_161116_52771.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_161116_52771.jpg
#   inflating: data/train/Barchino/20130305_165423_11424.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_165423_11424.jpg
#   inflating: data/train/Barchino/20130307_094258_51844.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130307_094258_51844.jpg
#   inflating: data/train/Barchino/20130304_081025_30577.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_081025_30577.jpg
#   inflating: data/train/Barchino/20130304_080553_29871.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_080553_29871.jpg
#   inflating: data/train/Barchino/20130304_142335_35277.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_142335_35277.jpg
#   inflating: data/train/Barchino/20130306_071512_16132.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130306_071512_16132.jpg
#   inflating: data/train/Barchino/20130410_112611_76901.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130410_112611_76901.jpg
#   inflating: data/train/Barchino/20130304_142333_35266.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_142333_35266.jpg
#   inflating: data/train/Barchino/20130304_170106_59590.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_170106_59590.jpg
#   inflating: data/train/Barchino/20130410_151329_18392.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130410_151329_18392.jpg
#   inflating: data/train/Barchino/20130306_073836_20371.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130306_073836_20371.jpg
#   inflating: data/train/Barchino/20130307_072452_23250.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130307_072452_23250.jpg
#   inflating: data/train/Barchino/20130307_082728_35772.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130307_082728_35772.jpg
#   inflating: data/train/Barchino/20130304_145826_42040.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_145826_42040.jpg
#   inflating: data/train/Barchino/20130305_152259_99521.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_152259_99521.jpg
#   inflating: data/train/Barchino/20130305_114530_69047.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_114530_69047.jpg
#   inflating: data/train/Barchino/20130410_154244_22510.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130410_154244_22510.jpg
#   inflating: data/train/Barchino/20130304_145147_40831.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_145147_40831.jpg
#   inflating: data/train/Barchino/20130304_074602_25752.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_074602_25752.jpg
#   inflating: data/train/Barchino/20130304_144159_39015.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_144159_39015.jpg
#   inflating: data/train/Barchino/20130305_162659_08269.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_162659_08269.jpg
#   inflating: data/train/Barchino/20130306_093008_39802.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130306_093008_39802.jpg
#   inflating: data/train/Barchino/20130305_092359_44749.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_092359_44749.jpg
#   inflating: data/train/Barchino/20130410_154756_23562.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130410_154756_23562.jpg
#   inflating: data/train/Barchino/20130305_163452_08865.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_163452_08865.jpg
#   inflating: data/train/Barchino/20130410_092026_53335.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130410_092026_53335.jpg
#   inflating: data/train/Barchino/20130306_134826_76021.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130306_134826_76021.jpg
#   inflating: data/train/Barchino/20130305_141413_90561.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_141413_90561.jpg
#   inflating: data/train/Barchino/20130410_160014_25844.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130410_160014_25844.jpg
#   inflating: data/train/Barchino/20130304_165956_59445.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_165956_59445.jpg
#   inflating: data/train/Barchino/20130307_145845_00315.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130307_145845_00315.jpg
#   inflating: data/train/Barchino/20130304_082648_34430.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_082648_34430.jpg
#   inflating: data/train/Barchino/20130305_093748_46935.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_093748_46935.jpg
#   inflating: data/train/Barchino/20130304_170108_59619.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_170108_59619.jpg
#   inflating: data/train/Barchino/20130410_155346_24232.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130410_155346_24232.jpg
#   inflating: data/train/Barchino/20130304_140955_33241.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_140955_33241.jpg
#   inflating: data/train/Barchino/20130304_084533_38183.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_084533_38183.jpg
#   inflating: data/train/Barchino/20130304_143313_36931.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_143313_36931.jpg
#   inflating: data/train/Barchino/20130306_074111_20802.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130306_074111_20802.jpg
#   inflating: data/train/Barchino/20130410_100704_62186.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130410_100704_62186.jpg
#   inflating: data/train/Barchino/20130304_155259_50213.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_155259_50213.jpg
#   inflating: data/train/Barchino/20130305_162413_07988.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_162413_07988.jpg
#   inflating: data/train/Barchino/20130304_160505_51230.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_160505_51230.jpg
#   inflating: data/train/Barchino/20130307_104319_63409.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130307_104319_63409.jpg
#   inflating: data/train/Barchino/20130304_161522_53235.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_161522_53235.jpg
#   inflating: data/train/Barchino/20130304_153151_47138.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_153151_47138.jpg
#   inflating: data/train/Barchino/20130305_093751_47033.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_093751_47033.jpg
#   inflating: data/train/Barchino/20130305_092400_44886.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_092400_44886.jpg
#   inflating: data/train/Barchino/20130304_072143_21529.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_072143_21529.jpg
#   inflating: data/train/Barchino/20130304_150413_42703.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_150413_42703.jpg
#   inflating: data/train/Barchino/20130410_164211_03532.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130410_164211_03532.jpg
#   inflating: data/train/Barchino/20130305_143948_94266.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_143948_94266.jpg
#   inflating: data/train/Barchino/20130305_135358_86286.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_135358_86286.jpg
#   inflating: data/train/Barchino/20130305_100216_51453.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_100216_51453.jpg
#   inflating: data/train/Barchino/20130304_154523_49077.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_154523_49077.jpg
#   inflating: data/train/Barchino/20130306_084946_32958.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130306_084946_32958.jpg
#   inflating: data/train/Barchino/20130304_171111_60943.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_171111_60943.jpg
#   inflating: data/train/Barchino/20130305_075450_30640.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_075450_30640.jpg
#   inflating: data/train/Barchino/20130304_073413_23764.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_073413_23764.jpg
#   inflating: data/train/Barchino/20130305_113648_67792.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_113648_67792.jpg
#   inflating: data/train/Barchino/20130410_113959_79253.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130410_113959_79253.jpg
#   inflating: data/train/Barchino/20130304_155812_50679.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_155812_50679.jpg
#   inflating: data/train/Barchino/20130307_153040_04544.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130307_153040_04544.jpg
#   inflating: data/train/Barchino/20130305_084358_38706.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_084358_38706.jpg
#   inflating: data/train/Barchino/20130410_132955_01169.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130410_132955_01169.jpg
#   inflating: data/train/Barchino/20130304_082759_34839.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_082759_34839.jpg
#   inflating: data/train/Barchino/20130305_073915_27325.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_073915_27325.jpg
#   inflating: data/train/Barchino/20130304_072756_22929.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_072756_22929.jpg
#   inflating: data/train/Barchino/20130305_160408_04882.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_160408_04882.jpg
#   inflating: data/train/Barchino/20130305_081323_33210.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_081323_33210.jpg
#   inflating: data/train/Barchino/20130307_094255_51753.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130307_094255_51753.jpg
#   inflating: data/train/Barchino/20130305_112520_66215.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_112520_66215.jpg
#   inflating: data/train/Barchino/20130305_105353_59838.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130305_105353_59838.jpg
#   inflating: data/train/Barchino/20130306_121038_63939.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130306_121038_63939.jpg
#   inflating: data/train/Barchino/20130304_165137_58704.jpg
#   inflating: __MACOSX/data/train/Barchino/._20130304_165137_58704.jpg
#   inflating: __MACOSX/data/train/._Barchino
#    creating: data/train/Motopontonerettangolare/
#   inflating: data/train/Motopontonerettangolare/20130410_125016_93082.jpg
#    creating: __MACOSX/data/train/Motopontonerettangolare/
#   inflating: __MACOSX/data/train/Motopontonerettangolare/._20130410_125016_93082.jpg
#   inflating: data/train/Motopontonerettangolare/20130305_134754_85449.jpg
#   inflating: __MACOSX/data/train/Motopontonerettangolare/._20130305_134754_85449.jpg
#   inflating: data/train/Motopontonerettangolare/20130307_090745_43571.jpg
#   inflating: __MACOSX/data/train/Motopontonerettangolare/._20130307_090745_43571.jpg
#   inflating: data/train/Motopontonerettangolare/20130306_062340_06111.jpg
#   inflating: __MACOSX/data/train/Motopontonerettangolare/._20130306_062340_06111.jpg
#   inflating: data/train/Motopontonerettangolare/20130305_062328_12371.jpg
#   inflating: __MACOSX/data/train/Motopontonerettangolare/._20130305_062328_12371.jpg
#   inflating: data/train/Motopontonerettangolare/20130307_061609_10266.jpg
#   inflating: __MACOSX/data/train/Motopontonerettangolare/._20130307_061609_10266.jpg
#   inflating: data/train/Motopontonerettangolare/20130306_104651_52563.jpg
#   inflating: __MACOSX/data/train/Motopontonerettangolare/._20130306_104651_52563.jpg
#   inflating: data/train/Motopontonerettangolare/20130410_094753_59078.jpg
#   inflating: __MACOSX/data/train/Motopontonerettangolare/._20130410_094753_59078.jpg
#   inflating: data/train/Motopontonerettangolare/20130305_134752_85443.jpg
#   inflating: __MACOSX/data/train/Motopontonerettangolare/._20130305_134752_85443.jpg
#   inflating: data/train/Motopontonerettangolare/20130307_061605_10139.jpg
#   inflating: __MACOSX/data/train/Motopontonerettangolare/._20130307_061605_10139.jpg
#   inflating: data/train/Motopontonerettangolare/20130410_125013_93057.jpg
#   inflating: __MACOSX/data/train/Motopontonerettangolare/._20130410_125013_93057.jpg
#   inflating: data/train/Motopontonerettangolare/20130304_063820_11725.jpg
#   inflating: __MACOSX/data/train/Motopontonerettangolare/._20130304_063820_11725.jpg
#   inflating: data/train/Motopontonerettangolare/20130304_134311_29014.jpg
#   inflating: __MACOSX/data/train/Motopontonerettangolare/._20130304_134311_29014.jpg
#   inflating: data/train/Motopontonerettangolare/20130306_135225_76614.jpg
#   inflating: __MACOSX/data/train/Motopontonerettangolare/._20130306_135225_76614.jpg
#   inflating: data/train/Motopontonerettangolare/20130305_105922_61080.jpg
#   inflating: __MACOSX/data/train/Motopontonerettangolare/._20130305_105922_61080.jpg
#   inflating: data/train/Motopontonerettangolare/20130410_051903_01754.jpg
#   inflating: __MACOSX/data/train/Motopontonerettangolare/._20130410_051903_01754.jpg
#   inflating: __MACOSX/data/train/._Motopontonerettangolare
#   inflating: __MACOSX/data/._train

# %% [markdown]
# We'll start by exploring the data, and look at how we can get that data loaded into memory through python code. We can just use the `ls` command from with this notebook to explore the data set:

# %%
# !ls data
# !ls data/test
# Out:
# mf.jpg	README.md  test  train	valid
# Alilaguna  Lanciafino10m	    Mototopo	     Sandoloaremi
# Ambulanza  Motobarca		    Patanella	     Topa
# Barchino   Motopontonerettangolare  Polizia	     VaporettoACTV
# Gondola    MotoscafoACTV	    Raccoltarifiuti  Water

# %% [markdown]
# If you explore the `data` directory you should see three folders:
#
# 	- The `train` folder contains the training data & is broken into subdirectories for each class.
# 	- The `valid` folder contains the validation data & is broken into subdirectories for each class.
# 	- The `test` folder contains the testing data & is broken into subdirectories for each class.
#
# The following displays one of the images:

# %%
from IPython.display import Image
Image("data/test/Alilaguna/20130412_064059_20202.jpg")

# %% [markdown]
# The `torchvision` library has support for directly reading images from a directory structure like the one we have using the `torchvision.datasets.ImageFolder` class. In addition to loading the images directly, `torchvision` provides a mechanism to dynamically augment the data being read by applying random transformations (flipping, rotating, etc), as well as cropping and scaling the images. The following code will generate a visualisation of the first batch of images produced by the data loader:

# %%
# %matplotlib inline

# Plot ad hoc data instances
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
from torchvision import transforms 
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import numpy

transform = transforms.Compose([
    transforms.Resize((240, 800)),
    transforms.ToTensor()  # convert to tensor
])

train_dataset = ImageFolder("data/train", transform)
train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True)

# generate the first batch
(batch_images, batch_labels) = train_loader.__iter__().__next__()

# plot 4 images
plt.subplot(221).set_title(train_dataset.classes[batch_labels[0]])
plt.imshow(batch_images[0].permute(1, 2, 0), aspect='equal')
plt.subplot(222).set_title(train_dataset.classes[batch_labels[1]])
plt.imshow(batch_images[1].permute(1, 2, 0), aspect='equal')
plt.subplot(223).set_title(train_dataset.classes[batch_labels[2]])
plt.imshow(batch_images[2].permute(1, 2, 0), aspect='equal')
plt.subplot(224).set_title(train_dataset.classes[batch_labels[3]])
plt.imshow(batch_images[3].permute(1, 2, 0), aspect='equal')

# show the plot
plt.show()

# %% [markdown]
# ## A simple CNN for boat classification
#
# Now let's try something a little more challenging and take our `BetterCNN` convolutional network from the experiments with mnist last week, and apply it to the problem of boat classification. Firstly we need to setup the data for training, and it would also be sensible to load the validation data to monitor performance during training, as well as load the test data:

# %%
# the number of images that will be processed in a single step
batch_size=128
# the size of the images that we'll learn on - we'll shrink them from the original size for speed
image_size=(30, 100)

transform = transforms.Compose([
    transforms.Resize(image_size),
    transforms.ToTensor()  # convert to tensor
])

train_dataset = ImageFolder("data/train", transform)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

val_dataset = ImageFolder("data/valid", transform)
val_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)

test_dataset = ImageFolder("data/test", transform)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# Note that for now we're not using any data augmentation from the training data, however we've structured the code so that we can easily add it by manipulating the transforms that are applied. Note that if we dot that, we probably wouldn't want to do the augmentation of the validation/test sets, so we would need a separate set of transforms for those.
#
# Now we can add the network definition from last week. We'll make a slight change to the previous `BetterCNN` function so that it allows us to specify the number of input channels and the number of output classes in the constructor. In the following block you'll need to paste your implementation of the `BetterCNN` forward method from last week:

# %%
import torch 
import torch.nn.functional as F
from torch import nn

# Model Definition
class BetterCNN(nn.Module):
    def __init__(self, n_channels_in, n_classes):
        super(BetterCNN, self).__init__()
        self.conv1 = nn.Conv2d(n_channels_in, 30, (5, 5), padding=0)
        self.conv2 = nn.Conv2d(30, 15, (3, 3), padding=0)
        self.fc1 = nn.Linear(1725, 128)
        self.fc2 = nn.Linear(128, 50)
        self.fc3 = nn.Linear(50, n_classes)
    
    def forward(self, x):
      out = self.conv1(x)
      out = F.relu(out)
      out = F.max_pool2d(out,(2,2))
      out = self.conv2(out)
      out = F.relu(out)
      out = F.max_pool2d(out,(2,2))
      out = F.dropout(out,0.2)
      out = out.view(out.shape[0],-1)
      out = self.fc1(out)
      out = F.relu(out)
      out = self.fc2(out)
      out = F.relu(out)
      out = self.fc3(out)
      return out

# %% [markdown]
# We're now in a position to add the code to fit the model - we'll use `torchbearer` to help us out:

# %%
import torchbearer
from torchbearer import Trial
from torch import optim

model = BetterCNN(3, len(train_dataset.classes))

# define the loss function and the optimiser
loss_function = nn.CrossEntropyLoss()
optimiser = optim.Adam(model.parameters())

device = "cuda:0" if torch.cuda.is_available() else "cpu"
trial = Trial(model, optimiser, loss_function, metrics=['loss', 'accuracy']).to(device)
trial.with_generators(train_loader, val_generator=val_loader, test_generator=test_loader)
trial.run(epochs=10)
results = trial.evaluate(data_key=torchbearer.VALIDATION_DATA)
print()
print(results)
# Out:
# HBox(children=(IntProgress(value=0, description='0/10(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='0/10(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='1/10(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='1/10(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='2/10(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='2/10(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='3/10(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='3/10(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='4/10(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='4/10(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='5/10(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='5/10(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='6/10(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='6/10(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='7/10(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='7/10(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='8/10(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='8/10(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='9/10(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='9/10(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='0/1(e)', max=28, style=ProgressStyle(description_width='initi…
# {'val_loss': 0.7685753703117371, 'val_acc': 0.7550374269485474}

# %% [markdown]
# Once the model is trained, we can investigate the performance on the test data. Rather than just look at the average accuracy we need to dig into a little more detail, so we'll use the `classification_report` method in scikit-learn to compute per-class precision and recall values:

# %%
predictions = trial.predict()
predicted_classes = predictions.argmax(1).cpu()
true_classes = list(x for (_,x) in test_dataset.samples)

from sklearn import metrics
print(metrics.classification_report(true_classes, predicted_classes, target_names=train_dataset.classes))
# Out:
# HBox(children=(IntProgress(value=0, description='0/1(p)', max=11, style=ProgressStyle(description_width='initi…
#                          precision    recall  f1-score   support
#
#               Alilaguna       0.71      0.63      0.67        19
#               Ambulanza       0.17      0.09      0.12        22
#                Barchino       0.00      0.00      0.00        51
#                 Gondola       0.00      0.00      0.00         3
#           Lanciafino10m       0.00      0.00      0.00         7
#               Motobarca       0.08      0.02      0.03        59
# Motopontonerettangolare       1.00      0.33      0.50         3
#           MotoscafoACTV       0.00      0.00      0.00         1
#                Mototopo       0.64      0.90      0.75       274
#               Patanella       0.33      0.64      0.44        74
#                 Polizia       0.00      0.00      0.00        15
#         Raccoltarifiuti       0.00      0.00      0.00        19
#            Sandoloaremi       0.00      0.00      0.00         3
#                    Topa       0.00      0.00      0.00        29
#           VaporettoACTV       0.98      0.98      0.98       325
#                   Water       0.94      0.97      0.96       420
#
#                accuracy                           0.78      1324
#               macro avg       0.30      0.28      0.28      1324
#            weighted avg       0.71      0.78      0.74      1324
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# In this particular case you should observe that the overall accuracies are a bit mixed; whist the average is high, it is clear that our model doesnt work well for some classes. Be aware though that we're using a relatively small set of both training and validation data, and that there is a very high bias in the class distribution which inevitably could lead to higher accuracies because of common classes. As we mentioned in the lab last week, this network architecture isn't any thing like one that has won the image classification challenges.

# %% [markdown]
# ## Using a better network model - transferring and finetuning a pretrained ResNet
#
# Training a network from scratch can be a lot of work. Is there some way we could take an existing network trained on some data with one set of labels, and adapt it to work on a different data set with different labels? Assuming that the inputs of the network are equivalent (for example, image with the same number of bands and size), then the answer is an emphatic yes! This process of "finetuning" a pre-trained network has become common-place as its much faster an easier than starting from scratch. This approach will also help us better work with the small amount of data that we have to train with.
#
# Let's try this in practice - we'll start by loading a pre-trained network architecture called a Deep Residual Network (or ResNet for short) that has been trained on the 1000-class ImageNet dataset. The ResNet architecture is very deep - it has many (in our case 50) convolutional layers and is currently one of the best performing architectures on the ImageNet challenge. The PyTorch model zoo contains code that implements the resnet50 architecture, and automatically downloads the pre-trained model weights. We'll start by using this to load the model and test it by classifying an image:

# %%
from torchvision.models import resnet50
from urllib.request import urlopen

imagenet_labels = urlopen("https://raw.githubusercontent.com/Lasagne/Recipes/master/examples/resnet50/imagenet_classes.txt").read().decode('utf-8').split("\n")

model = resnet50(pretrained=True)
model.eval()

preprocess_input = transforms.Compose([
            transforms.Resize(224),
            transforms.CenterCrop(224),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225]),
        ])

from PIL import Image as PImage
img_path = 'data/mf.jpg'
img = PImage.open(img_path)

print(preprocess_input(img))
preds = model(preprocess_input(img).unsqueeze(0))

_, indexes = preds.topk(5)
for i in indexes[0]:
    print('Predicted:', imagenet_labels[i])
# Out:
# tensor([[[ 0.7762,  0.7762,  0.7762,  ...,  0.6734,  0.6734,  0.6734],
#          [ 0.8104,  0.8104,  0.8104,  ...,  0.7248,  0.7248,  0.7077],
#          [ 0.8104,  0.8276,  0.8276,  ...,  0.7933,  0.7762,  0.7419],
#          ...,
#          [-1.4500, -1.1418, -1.3302,  ..., -0.9705,  0.1426,  0.0227],
#          [-1.4843, -1.5357, -1.5528,  ..., -0.3369, -0.3541, -0.4226],
#          [-1.6555, -1.8097, -1.5699,  ..., -0.0287, -0.5082, -0.6794]],
#
#         [[ 0.9230,  0.9230,  0.9230,  ...,  0.8354,  0.8354,  0.8354],
#          [ 0.9580,  0.9580,  0.9580,  ...,  0.8880,  0.8880,  0.8704],
#          [ 0.9580,  0.9755,  0.9755,  ...,  0.9580,  0.9405,  0.9055],
#          ...,
#          [-1.5630, -1.2829, -1.4230,  ..., -1.2479, -0.1275, -0.3200],
#          [-1.5805, -1.6681, -1.6331,  ..., -0.5476, -0.6001, -0.7402],
#          [-1.7556, -1.9132, -1.6155,  ..., -0.2500, -0.7752, -0.9328]],
#
#         [[ 1.1759,  1.1759,  1.1759,  ...,  1.1237,  1.1237,  1.1237],
#          [ 1.2108,  1.2108,  1.2108,  ...,  1.1759,  1.1759,  1.1585],
#          [ 1.2108,  1.2282,  1.2282,  ...,  1.2457,  1.2282,  1.1934],
#          ...,
#          [-1.5256, -1.2293, -1.3164,  ..., -1.2293, -0.3578, -0.4798],
#          [-1.4907, -1.5430, -1.4907,  ..., -0.6890, -0.8458, -0.8807],
#          [-1.5953, -1.7347, -1.4733,  ..., -0.5670, -0.9678, -1.0027]]])
# Predicted: barracouta, snoek
# Predicted: gar, garfish, garpike, billfish, Lepisosteus osseus
# Predicted: coho, cohoe, coho salmon, blue jack, silver salmon, Oncorhynchus kisutch
# Predicted: sturgeon
# Predicted: great white shark, white shark, man-eater, man-eating shark, Carcharodon carcharias

# %% [markdown]
# If you run the above code (it will take a little longer the first time as the model is downloaded), it should indicate that our input image was likely to contain a fish! Run the following block to display the image and verify this.
#
# The `preprocess_input` transformation in the above is important - it's responsible for applying the same normalisation operations to our input image as were applied to the images when the network was trained, as well as getting the image to the 224x224 size expected by the network.

# %%
Image("data/mf.jpg")

# %% [markdown]
# In the above code to load the pretrained ResNet model, after the model is loaded we call `model.eval()`. Why is this? What happens if you don't make this call before using the model? __Write your answers in the following block:__

# %% [markdown]
# Beacuese we need its freezon weight for evaluation, if not set, it will train the data

# %% [markdown]
# We're now in a position to start to hack the model structure. Fundamentally we need to first remove the classification layer at the end of the model and replace it with a new one (with a different number of classes). Let's print out the model structure:

# %%
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %% [markdown]
# Looking at the model we can see that really what we want to do is just replace the last fully connected layer with one with a different number of features. There are many ways in which PyTorch allows us to do this, but the simplest is to just do a direct replacement.
#
# We'll also make a small change to the pooling layer before the last fully connected layer; in the default ResNet model 2D average pooling is used to reduce a 2048x7x7 tensor to 2048x1x1 by using a 7x7 pooling window. This is precisely the definition of Global Average Pooling, however it is implemented with a fixed size window. As our boat images are not square, it would be nice if we could use them at a high resolution without cropping. We can replace the pooling layer with an `nn.AdaptiveAvgPool2d` layer that will perform real Global Average Pooling by dynamically scaling the window to whatever spatial size the input feature maps have:

# %%
model = resnet50(pretrained=True)
model.avgpool = nn.AdaptiveAvgPool2d((1,1))
model.fc = nn.Linear(2048, len(train_dataset.classes))
model.train()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=16, bias=True)
# )

# %% [markdown]
# The actual process of finetuning involves us now training the model with our own data. As the network is already largely trained, we'll likely want to use a small learning rate so not to make big changes in weights. Often we'll first "freeze" the weights of the already trained layers whilst we learn initial weights for our new layer to avoid overfitting while training:

# %%
# Freeze layers by not tracking gradients
for param in model.parameters():
    param.requires_grad = False
model.fc.weight.requires_grad = True #unfreeze last layer weights
model.fc.bias.requires_grad = True #unfreeze last layer biases

optimiser = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=1e-3) #only optimse non-frozen layers

# %% [markdown]
# If we have lots of training data we could then unlock these layers and perform end-to-end finetuning afterwards. The Standford CS231n course pages have lots of useful hints on fine-tuning: http://cs231n.github.io/transfer-learning/
#
# __Use the following block to try finetuning the resnet50 with the boat data. You'll need a GPU to do this effectively as it's _rather_ slow!__

# %%
import torchbearer
from torchbearer import Trial
from torch import optim

#model = BetterCNN(3, len(train_dataset.classes))

# define the loss function and the optimiser
loss_function = nn.CrossEntropyLoss()
#optimiser = optim.Adam(model.parameters())

device = "cuda:0" if torch.cuda.is_available() else "cpu"
trial = Trial(model, optimiser, loss_function, metrics=['loss', 'accuracy']).to(device)
trial.with_generators(train_loader, val_generator=val_loader, test_generator=test_loader)
trial.run(epochs=15)
results = trial.evaluate(data_key=torchbearer.VALIDATION_DATA)
print()
print(results)
# Out:
# HBox(children=(IntProgress(value=0, description='0/15(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='0/15(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='1/15(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='1/15(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='2/15(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='2/15(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='3/15(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='3/15(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='4/15(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='4/15(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='5/15(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='5/15(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='6/15(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='6/15(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='7/15(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='7/15(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='8/15(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='8/15(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='9/15(t)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='9/15(v)', max=28, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='10/15(t)', max=28, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='10/15(v)', max=28, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='11/15(t)', max=28, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='11/15(v)', max=28, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='12/15(t)', max=28, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='12/15(v)', max=28, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='13/15(t)', max=28, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='13/15(v)', max=28, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='14/15(t)', max=28, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='14/15(v)', max=28, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='0/1(e)', max=28, style=ProgressStyle(description_width='initi…
# {'val_loss': 0.31977519392967224, 'val_acc': 0.9078871607780457}

# %% [markdown]
# Use the following block to note down the performance you achieve by finetuning the model. How does this compare to the `BetterCNN` model used earlier?

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Extracting features from a model
#
# Sometimes you want to do things that are not so easily accomplished with a deep network. You might want to build classifiers using very small amounts of data, or you might want a way of finding things in photographs that are in some way semantically similar, but don't have exactly the same classes. CNNs can actually help here using a technique known often called transfer learning (and related to the fine tuning that we just looked at). If we assume we have a trained network, then by extracting vectors from the layers before the final classifier we should have a means of achieving these tasks, as the vectors are likely to strongly encode semantic information about the content of the input image. If we wanted to quickly train new classifiers for new classes, we could for instance just use a relatively simple linear classifier trained on these vectors. If we wanted to find semantically similar images, we could just compare the Euclidean distance of these vectors.
#
# PyTorch makes it pretty easy to get these vector representations. The following code gets a resnet model in which the a feature vector is computed from the penultimate layer of the network by applying a _global average pooling_ operation over the feature maps:

# %%
from torch import nn
import torchbearer
from torchbearer import Trial
from torch import optim
device = "cuda:0" if torch.cuda.is_available() else "cpu"
model = resnet50(pretrained=True)
feature_extractor_model = nn.Sequential(*list(model.children())[:-2], nn.AdaptiveAvgPool2d((1,1)))
feature_extractor_model.eval()
feature_extractor_model = feature_extractor_model.to(device)

# %% [markdown]
# With this model, extract the features for some inputs. To demonstrate, we can put the whole thing together and generate a vector from an image:

# %%
transform = transforms.Compose([
    transforms.Resize((240, 800)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                          std=[0.229, 0.224, 0.225]),
])

img_path = 'data/test/Alilaguna/20130412_064059_20202.jpg'
img = PImage.open(img_path)
feature = feature_extractor_model(preprocess_input(img).unsqueeze(0).to(device))
print('Feature shape:', feature.shape)
print('Feature data:', feature[0].reshape(-1))
# Out:
# Feature shape: torch.Size([1, 2048, 1, 1])
# Feature data: tensor([0.2288, 0.6563, 0.0540,  ..., 0.0110, 0.6035, 0.1322], device='cuda:0',
#        grad_fn=<ViewBackward>)

# %% [markdown]
# Use the following block to generate some features for some different images in the test set, and calculate the Euclidean distances between these features.

# %%
import numpy as np
img_path1 = 'data/test/Alilaguna/20130412_064059_20202.jpg'
img_path2 = 'data/test/Barchino/20130412_055144_08007.jpg'
img_path3 = 'data/test/Mototopo/20130412_043218_54895.jpg'
img_path4 = 'data/test/Polizia/20130412_064335_20787.jpg'
img_path5 = 'data/test/Polizia/20130412_073326_31998.jpg'
img = []
img.append(PImage.open(img_path1))
img.append(PImage.open(img_path2))
img.append(PImage.open(img_path3))
img.append(PImage.open(img_path4))
img.append(PImage.open(img_path5))
feature = []
for i in range(5):
  feat = feature_extractor_model(preprocess_input(img[i]).unsqueeze(0).to(device))
  feature.append(feat[0].reshape(-1).cuda().data.cpu().numpy())
print('Feature shape:', len(feature),feature[0].shape)
feature = np.array((feature))
print(feature.shape)
print(feature)
#print('Feature data:', feature[0].reshape(-1))
# Out:
# Feature shape: 5 (2048,)
# (5, 2048)
# [[0.22881605 0.65630394 0.0539822  ... 0.01095866 0.6035098  0.13217016]
#  [0.02330888 0.5362003  0.13720639 ... 0.02319565 0.02002763 0.13709493]
#  [0.27843398 0.26051763 0.25549704 ... 0.09219142 0.12505597 0.12427912]
#  [0.5327932  0.16220757 0.14365241 ... 0.0148204  0.39412478 0.27875435]
#  [0.23076719 0.3162266  0.17252056 ... 0.05466196 0.09001268 0.02945487]]

# %%
from sklearn.metrics import pairwise_distances
dists = pairwise_distances(feature,feature)
print(dists)
# Out:
# [[ 0.       18.179865 16.668959 15.287805 17.693556]
#  [18.179865  0.       14.626805 16.074041 15.625138]
#  [16.668959 14.626805  0.       12.772678 14.316942]
#  [15.287805 16.074041 12.772678  0.       13.526529]
#  [17.693556 15.625138 14.316942 13.526529  0.      ]]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-9d09d934cc27> in <module>()
#       3 import matplotlib.pyplot as plt
#       4 plt.figure()
# ----> 5 plt.imshow(Image(img_path1))
#       6 plt.figure()
#       7 plt.imshow(img_path2)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2649         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2650         resample=resample, url=url, **({"data": data} if data is not
# -> 2651         None else {}), **kwargs)
#    2652     sci(__ret)
#    2653     return __ret
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
#     359
#     360     return wrapper
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
#     359
#     360     return wrapper
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5613                               resample=resample, **kwargs)
#    5614
# -> 5615         im.set_data(X)
#    5616         im.set_alpha(alpha)
#    5617         if im.get_clip_path() is None:
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/image.py in set_data(self, A)
#     692                 not np.can_cast(self._A.dtype, float, "same_kind")):
#     693             raise TypeError("Image data of dtype {} cannot be converted to "
# --> 694                             "float".format(self._A.dtype))
#     695
#     696         if not (self._A.ndim == 2
#
# TypeError: Image data of dtype object cannot be converted to float

# %% [markdown]
# In the following block describe how the Euclidean distances compare to your perception of similarity between the images:

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# Let's now explore how features from a ResNet could be used with a classifier that works well with small amounts of training data - a Support Vector Machine. Use the following block to train a multiclass SVM using the `sklearn.svm.SVC` class to learn the boat classes using the features extracted by the ResNet50 with the default imagenet weights. Once you've trained it (and optimised the parameters) print out a classification report.
#
# We've provided all the features and labels in the form of `numpy` arrays so you don't have to extract them (which can take a few minutes; you can view the code we used [here](https://github.com/ecs-vlc/COMP6248/blob/master/docs/labs/lab6/genfeats.py)):

# %%
import numpy as np

if not exists('training_features.npy'):
    # !wget -O Resnet50Features.zip https://artist-cloud.ecs.soton.ac.uk/index.php/s/P68OB07DquOwSR7/download
    # !unzip Resnet50Features.zip

training_features = np.load('training_features.npy')
training_labels = np.load('training_labels.npy')

valid_features = np.load('valid_features.npy')
valid_labels = np.load('valid_labels.npy')

testing_features = np.load('testing_features.npy')
testing_labels = np.load('testing_labels.npy')


from sklearn import svm

from sklearn.metrics import classification_report
clf=svm.SVC()
clf.fit(training_features,training_labels)
#在拟合后，这个模型可以用来预测新的分类值
y_true=testing_labels
y_pred=clf.predict(testing_features)

print(classification_report(y_true, y_pred, target_names=train_dataset.classes))
# Out:
#                          precision    recall  f1-score   support
#
#               Alilaguna       0.90      1.00      0.95        19
#               Ambulanza       0.82      0.82      0.82        22
#                Barchino       0.76      0.25      0.38        51
#                 Gondola       1.00      0.67      0.80         3
#           Lanciafino10m       0.00      0.00      0.00         7
#               Motobarca       0.82      0.31      0.44        59
# Motopontonerettangolare       1.00      1.00      1.00         3
#           MotoscafoACTV       0.00      0.00      0.00         1
#                Mototopo       0.82      0.99      0.89       274
#               Patanella       0.41      0.84      0.55        74
#                 Polizia       0.67      0.13      0.22        15
#         Raccoltarifiuti       1.00      0.74      0.85        19
#            Sandoloaremi       0.00      0.00      0.00         3
#                    Topa       0.00      0.00      0.00        29
#           VaporettoACTV       0.99      1.00      1.00       325
#                   Water       0.99      0.97      0.98       420
#
#                accuracy                           0.87      1324
#               macro avg       0.64      0.54      0.56      1324
#            weighted avg       0.87      0.87      0.85      1324
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# Use the following block to reflect on how the test performance compares to the finetuned ResNet. What is the difference in time taken to train and evaluate the different approaches?

# %% [markdown]
# YOUR ANSWER HERE
